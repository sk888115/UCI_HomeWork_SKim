# %%
import requests
import json

# %%
#url = "https://api.rawg.io/docs/?format=openapi"
url="https://api.rawg.io/api/games?dates=2019-10-10,2020-10-10&ordering=-added"
print(requests.get(url))
# Out:
# <Response [200]>

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "count": 117533,
#     "next": "https://api.rawg.io/api/games?dates=2019-10-10%2C2020-10-10&ordering=-added&page=2",
#     "previous": null,
#     "results": [
#         {
#             "added": 4638,
#             "added_by_status": {
#                 "beaten": 532,
#                 "dropped": 78,
#                 "owned": 2341,
#                 "playing": 228,
#                 "toplay": 1168,
#                 "yet": 291
#             },
#             "background_image": "https://media.rawg.io/media/games/2ad/2ad87a4a69b1104f02435c14c5196095.jpg",
#             "clip": {
#                 "clip": "https://media.rawg.io/media/stories-640/46b/46b2ab41014eb0d6b357fd9d155f90eb.mp4",
#                 "clips": {
#                     "320": "https://media.rawg.io/media/stories-320/7a5/7a5cd5eb8e382a76856d9fb66e4e4e31.mp4",
#                     "640": "https://media.rawg.io/media/stories-640/46b/46b2ab41014eb0d6b357fd9d155f90eb.mp4",
# ...

# %%
num_list = len(response['results'])
print(num_list)
# Out:
# 20
