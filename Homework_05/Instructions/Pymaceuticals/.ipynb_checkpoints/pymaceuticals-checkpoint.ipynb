# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_table = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="left")

# Display the data table for preview
merge_table.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
#mouse_count = len(merge_table["Mouse ID"].unique())
#mouse_count

num_mouse=merge_table['Mouse ID'].count()
num_mouse
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_rows = merge_table[merge_table.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_rows
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all_duplicate_rows = merge_table[merge_table.duplicated(['Mouse ID',])]
all_duplicate_rows
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_table.drop_duplicates("Mouse ID")
clean_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_num_mice = len(clean_df["Mouse ID"].unique())
clean_num_mice
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
drug_regimen = merge_table.groupby('Drug Regimen')

mean = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
stdv = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = merge_table.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary dataframe.
summary_df = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": stdv, 
                          "SEM": sem})
summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line
aggregate_summary = drug_regimen.agg({'Tumor Volume (mm3)': ['mean', 'median', 'var', 'std', 'sem']})
aggregate_summary
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
grouped_df = pd.DataFrame(merge_table.groupby(["Drug Regimen"]).count()).reset_index()

regimen_datapoints = grouped_df[["Drug Regimen","Mouse ID"]]
regimen_datapoints = regimen_datapoints.rename(columns={"Mouse ID": "Count"})
regimen_datapoints = regimen_datapoints.set_index("Drug Regimen")

regimen_datapoints.plot(kind="bar", figsize=(10,3))

plt.title("Total Unique Mice Count per Drug Regimen")
plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

x_axis = np.arange(len(regimen_datapoints))
tick_locations = [i for i in x_axis]
xtickers = [value for value in regimen_datapoints.index]
y_axis = [value for value in regimen_datapoints]

plt.bar(x_axis, y_axis, color='b', alpha=0.5, align='center')
plt.xticks(tick_locations, xtickers, rotation='vertical')
plt.xlabel('Drug Regimen')
plt.ylabel('Count')
plt.tight_layout()
plt.title("Total Unique Mice Count per Drug Regimen")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_df = pd.DataFrame(merge_table.groupby(["Sex"]).count()).reset_index()
gender_df.head()

gender_df = gender_df[["Sex","Mouse ID"]]
gender_df.head()

plt.figure(figsize=(12,6))
ax1 = plt.subplot(121, aspect="equal")
gender_df.plot(kind="pie", y = "Mouse ID", ax=ax1, autopct='%1.1f%%',
              startangle=190, shadow=True, labels=gender_df["Sex"], legend = False, fontsize=14)

plt.title("Male & Female Mice Percentage")
# Out:
# Text(0.5, 1.0, 'Male & Female Mice Percentage')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_count = (merge_table.groupby(["Sex"])["Age_months"].count()).tolist()
labels = ["Females", "Males"]
colors = ["purple", "orange"]
explode = (0.1, 0)

plt.pie(gender_count, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=160)
plt.axis("equal")

plt.title("Male & Female Mice Percentage")
# Out:
# Text(0.5, 1.0, 'Male & Female Mice Percentage')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
###sorted_df = merge_table.sort_values(["Drug Regimen", "Mouse ID", "Timepoint"])
###last_df = sorted_df.sort_values(["Timepoint"],ascending=False)
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

last_df = merge_table.drop_duplicates(subset='Mouse ID', keep='last')
last_df
last_df.reset_index()
# Out:
#      index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        9     k403     Ramicane    Male          21          16         45
# 1       19     s185    Capomulin  Female           3          17         45
# 2       29     x401    Capomulin  Female          16          15         45
# 3       39     m601    Capomulin    Male          22          17         45
# 4       49     g791     Ramicane    Male          11          16         45
# ..     ...      ...          ...     ...         ...         ...        ...
# 244   1859     z314     Stelasyn  Female          21          28          5
# 245   1862     z435     Propriva  Female          12          26         10
# 246   1872     z581    Infubinol  Female          24          25         45
# 247   1882     z795     Naftisol  Female          13          29         45
# 248   1892     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = {
    'Capomulin': [], 'Ramicane': [], 'Infubinol': [], 'Ceftamin': [] }

# Locate the rows which contain mice on each drug and get the tumor volumes
for i in range(len(last_df)):
    index = last_df.index[i]
    treatment = last_df['Drug Regimen'][index]
    vol = last_df['Tumor Volume (mm3)'][index]
    for drug in treatments:
        if treatment == drug:
            tumor_vol_data[treatment].append(vol)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
potential_outliers = {
    'Capomulin': [], 'Ramicane': [], 'Infubinol': [], 'Ceftamin': [] }

for treatment in tumor_vol_data:
    curr_df = last_df.loc[last_df['Drug Regimen'] == treatment]
    quartiles = curr_df['Tumor Volume (mm3)'].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    print(f"Lower quartile of tumor volume for {treatment}: {lowerq}.")
    print(f"Upper quartile of tumor volume for {treatment}: {upperq}.")
    print(f"Interquartile range for {treatment}: {iqr}.")
    print(f"Median of tumor volume for {treatment}: {quartiles[0.5]}. \n")
    
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)

    # Add to potential_outliers list
    for vol in tumor_vol_data[treatment]:
        if (vol < lower_bound) | (vol > upper_bound):
            potential_outliers[treatment].append(vol)

# Print the number of potential outliers for each treatment
for treatment in potential_outliers:
    print(f"There are {len(potential_outliers[treatment])} potential outlier(s) for {treatment}.")
# Out:
# Lower quartile of tumor volume for Capomulin: 32.37735684.
# Upper quartile of tumor volume for Capomulin: 40.1592203.
# Interquartile range for Capomulin: 7.781863460000004.
# Median of tumor volume for Capomulin: 38.125164399999996.
#
# Lower quartile of tumor volume for Ramicane: 31.56046955.
# Upper quartile of tumor volume for Ramicane: 40.65900627.
# Interquartile range for Ramicane: 9.098536719999998.
# Median of tumor volume for Ramicane: 36.56165229.
#
# Lower quartile of tumor volume for Infubinol: 54.04860769.
# Upper quartile of tumor volume for Infubinol: 65.52574285.
# Interquartile range for Infubinol: 11.477135160000003.
# Median of tumor volume for Infubinol: 60.16518046.
#
# Lower quartile of tumor volume for Ceftamin: 48.72207785.
# Upper quartile of tumor volume for Ceftamin: 64.29983003.
# Interquartile range for Ceftamin: 15.577752179999997.
# Median of tumor volume for Ceftamin: 59.85195552.
#
# There are 0 potential outlier(s) for Capomulin.
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
for treatment in tumor_vol_data:
    fig1, ax1 = plt.subplots()
    ax1.set_title(f"Final Tumor Volumes Of Each Mouse for {treatment}")
    ax1.set_ylabel('Tumor Volume (mm3)')
    ax1.boxplot(tumor_vol_data[treatment])
    plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Gather data for a single capomulin mouse with its Mouse ID
capomulin_mouse = merge_table.loc[(merge_table['Drug Regimen'] == 'Capomulin') & (merge_table['Mouse ID'] == 'x401')]

# Line Plot
plt.plot(capomulin_mouse['Timepoint'], capomulin_mouse['Tumor Volume (mm3)'], color='blue', label='Capomulin')
plt.title('Time Point vs. Tumor Volume for Mouse x401 treated with Capomulin')
plt.legend(loc='best')
plt.xlabel('Time Point')
plt.ylabel('Tumer Volume')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_mice = merge_table.loc[merge_table['Drug Regimen'] == 'Capomulin']
capomulin_mice = capomulin_mice.set_index('Mouse ID')
capomulin_mice = capomulin_mice.groupby(level=0).mean()

# for each mouse ID, create average tumor volume and mouse weight
average_tumor_volume = []
average_mouse_weight = []


for i in range(len(capomulin_mice)):
    average_tumor_volume.append(capomulin_mice['Weight (g)'][i])
    average_mouse_weight.append(capomulin_mice['Tumor Volume (mm3)'][i])

plt.scatter(average_tumor_volume, average_mouse_weight)
plt.xlabel('Average Tumor Volume')
plt.ylabel('Average Mouse Weight')
plt.title('Avg Mouse Weight vs. Avg Tumor Volume for Capomulin Regimen')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
from scipy.stats import linregress

# for mouse weight and average tumor volume for the Capomulin regimen
x_values = capomulin_mice['Tumor Volume (mm3)']
y_values = capomulin_mice['Weight (g)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The correlation coefficient is {rvalue}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (35, 22), fontsize=13, color='red')
plt.xlabel('Average Tumor Volume')
plt.ylabel('Average Mouse Weight')
plt.title('Linear Regression of Avg Mouse Weight vs. Avg Tumor Volume for Capomulin Regimen')
plt.show()
# Out:
# The correlation coefficient is 0.8419363424694718

# %% [markdown]
# # Observation
#
# 1. Mouse weight has positive linear correlation with Tumor Volume for Capomulin Regimen.
#
# 2. Infubinol seems to be the only treatment with outlier. (But this information has limitation. Other sample sets might have different result with the testing above.)
#
# 3. The tumor volume of the mice that are treated with Capomulin tend to decrease as Time Point increases.
